# %% [markdown]
# # Live-Dead Analysis

# %% [markdown]
# Conduct Live-Dead Quantification. First test parameters (mean shift array, erosion) then input into final quantification function

# %%
from Live_Dead_Functions import *

# %%
folder_path = '/Users/allisonpickle/Desktop/251322_24hr_LPS_LD'
print(folder_path)

# %%
Mean_Shift_Array(folder_path, show_test=True, save=False)

# %%
#Input chosen spatial and color radius
SR = 20
CR = 20
Apply_Otsu(folder_path, SR, CR, save=True, display=False)

# %%
folder_path = folder_path+ '/Thresholded'
print(folder_path)

# %%
#Only applies to C_1 Live Images
Erosion_Test(folder_path, S1=3, S2=5, S3=7, display=True, save=False)

# %% [markdown]
# START OFFICIAL LIVE-DEAD HERE ON BACKGROUND-SUBTRACTED IMAGES

# %%
folder_path = '/Users/allisonpickle/Desktop/251322_24hr_LPS_LD/All'

SR = 20
CR = 20
Erosion_Size = 5
Minimum_distance = 10
Calculate_Live_Dead(folder_path, SR, CR, Erosion_Size, Minimum_distance, display=False, save=True)

# %% [markdown]
# ## VISUALIZATION

# %%
from bioimagebook_Functions import *

# %%
from Live_Dead_Visualization import *

# %%
folder_path = '/Users/allisonpickle/Desktop/Wash Test'

# %%
optimize_contrast(folder_path, display=False, save=True)

# %%
Colorize_Composite(folder_path, display_results=False, save_results=True)

# %% [markdown]
# Designate a new folder for different magnification images

# %%
folder_path = '/Users/allisonpickle/Desktop/251322_24hr_LPS_LD/All/Colorized'

# %%
Objective = 10
# Objective = 20
Apply_Scale_Bar(folder_path, Objective, display=False, save=True)

# %% [markdown]
# Stack colorized images into rows or columns

# %%
# folder_path = '/Users/allisonpickle/Desktop/250724_LiveDead_Hippo_cort/Plate 1/All/1_Background Subtraction/Colorized'
Stack_Images_Row(folder_path)

# %%
Stack_Images_Column(folder_path)
